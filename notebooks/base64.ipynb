# %%
import base64

# %%
# https://sistemaswebb3-listados.b3.com.br/fundsListedProxy/Search/GetDetailFund/

print(base64.b64decode("eyJsYW5ndWFnZSI6InB0LWJyIiwiaWRGTkVUIjo4MDM4LCJpZENFTSI6IkFHUkkiLCJ0eXBlRnVuZCI6IkVURiJ9"))

# {
#     "idFNET": 8038,
#     "typeFNET": "ETF",
#     "type": 3,
#     "typeName": "ETF",
#     "acronym": "AGRI",
#     "tradingName": "BB ETF IAGRO",
#     "tradingCode": "AGRI11",
#     "tradingCodeOthers": "AGRI11T",
#     "cnpj": "45081470000165",
#     "classification": null,
#     "webSite": "",
#     "fundAddress": "AV REPUBLICA DO CHILE, 330 - 7º ANDAR TORRE OESTE, RJ, RIO DE JANEIRO, CENTRO - CEP: 20031170",
#     "fundPhoneNumberDDD": "21 ",
#     "fundPhoneNumber": "38087505",
#     "fundPhoneNumberFax": null,
#     "positionManager": "BB GESTAO DE RECURSOS DTVM S.A",
#     "managerName": "CAROLINA CORREA DE ALBUQUERQUE",
#     "fundName": "BB ETF IAGRO-FFS B3 FUNDO DE ÍNDICE RESPONSABILIDADE LIMITADA",
#     "quotaCount": "5.000.000",
#     "quotaDateApproved": "26/12/2024",
#     "segment": "Bolsa",
#     "shareHolder": {
#         "shareHolderName": "BRASIL",
#         "shareHolderAddress": "RUA LELIO GAMA 104 - 38.ANDAR - CEP: 20031080   - RIO DE JANEIRO - RJ",
#         "shareHolderPhoneNumberDDD": "",
#         "shareHolderPhoneNumber": "552138083715",
#         "shareHolderFaxNumber": "20031080",
#         "shareHolderEmail": "aescriturais@bb.com.br"
#     },
#     "classes": null
# }
# Out:
# b'{"language":"pt-br","idFNET":8038,"idCEM":"AGRI","typeFund":"ETF"}'

# %%
# https://sistemaswebb3-listados.b3.com.br/fundsListedProxy/Search/GetListFunds/

print(base64.b64decode("eyJsYW5ndWFnZSI6InB0LWJyIiwidHlwZUZ1bmQiOiJFVEYtRklJIiwicGFnZU51bWJlciI6MSwicGFnZVNpemUiOjIwfQ=="))
print(base64.b64decode("eyJsYW5ndWFnZSI6InB0LWJyIiwidHlwZUZ1bmQiOiJFVEYtQ1JJUFRPIiwicGFnZU51bWJlciI6MSwicGFnZVNpemUiOjIwfQ=="))
print(base64.b64decode("eyJsYW5ndWFnZSI6InB0LWJyIiwidHlwZUZ1bmQiOiJFVEYtUkYiLCJwYWdlTnVtYmVyIjoxLCJwYWdlU2l6ZSI6MjB9"))
print(base64.b64decode("eyJsYW5ndWFnZSI6InB0LWJyIiwidHlwZUZ1bmQiOiJFVEYiLCJwYWdlTnVtYmVyIjoxLCJwYWdlU2l6ZSI6MjB9"))

# "id": 8038,
# "typeName": null,
# "acronym": "AGRI",
# "fundName": "BB ETF IAGRO-FFS B3 FUNDO DE ÍNDICE RESPONSABILIDADE LIMITADA",
# "tradingName": "BB ETF IAGRO"

# {
#     "page": {
#         "pageNumber": 1,
#         "pageSize": 20,
#         "totalRecords": 110,
#         "totalPages": 6
#     },
#     "results": [
#         {
#             "id": 8038,
#             "typeName": null,
#             "acronym": "AGRI",
#             "fundName": "BB ETF IAGRO-FFS B3 FUNDO DE ÍNDICE RESPONSABILIDADE LIMITADA",
#             "tradingName": "BB ETF IAGRO"
#         },
#         {
#             "id": 3665,
#             "typeName": null,
#             "acronym": "BBOV",
#             "fundName": "BB ETF IBOVESPA FUNDO DE ÍNDICE RESPONSABILIDADE LIMITADA",
#             "tradingName": "BB ETF IBOV"
#         },
#         {
#             "id": 15863,
#             "typeName": null,
#             "acronym": "BRAZ",
#             "fundName": "BB ETF ÍNDICE BOVESPA B3 BR+ FUNDO DE ÍNDICE RESPONSABILIDADE LIMITADA",
#             "tradingName": "BB ETF BRAZ"
#         },
#         {
#             "id": 10719,
#             "typeName": null,
#             "acronym": "DVER",
#             "fundName": "BB ETF ÍNDICE DIVERSIDADE B3 INVESTIMENTO SUSTENTÁVEL FUNDO DE ÍNDICE RESPONSABILIDADE LIMITADA",
#             "tradingName": "BB ETF DVER"
#         },
#         {
#             "id": 8892,
#             "typeName": null,
#             "acronym": "BBOI",
#             "fundName": "BB ETF ÍNDICE FUTURO DE BOI GORDO B3 FUNDO DE ÍNDICE RESPONSABILIDADE LIMITADA",
#             "tradingName": "BB ETF BOI G"
#         },
#         {
#             "id": 12629,
#             "typeName": null,
#             "acronym": "DOLA",
#             "fundName": "BB ETF ÍNDICE FUTURO DE DOLAR S&P/B3 FUNDO DE ÍNDICE RESPONSABILIDADE LIMITADA",
#             "tradingName": "BB ETF DOLAR"
#         },
#         {
#             "id": 8748,
#             "typeName": null,
#             "acronym": "CORN",
#             "fundName": "BB ETF ÍNDICE FUTURO DE MILHO B3 FUNDO DE ÍNDICE RESPONSABILIDADE LIMITADA",
#             "tradingName": "BB ETF MILHO"
#         },
#         {
#             "id": 987,
#             "typeName": null,
#             "acronym": "BBSD",
#             "fundName": "BB ETF S&P DIVIDENDOS BRASIL FUNDO DE ÍNDICE RESPONSABILIDADE LIMITADA",
#             "tradingName": "BB ETF SP DV"
#         },
#         {
#             "id": 19536,
#             "typeName": null,
#             "acronym": "TECX",
#             "fundName": "B-INDEX ETF CONNECT CHINA AMC CHINEXT FUNDO DE ÍNDICE - RESP LIMITADA",
#             "tradingName": "B INDEX TECX"
#         },
#         {
#             "id": 18957,
#             "typeName": null,
#             "acronym": "PKIN",
#             "fundName": "B-INDEX ETF CONNECT CHINA UNIVERSAL CSI 300 FUNDO DE ÍNDICE - RESP LIMITADA",
#             "tradingName": "B INDEX PKIN"
#         },
#         {
#             "id": 23759,
#             "typeName": null,
#             "acronym": "OURO",
#             "fundName": "B-INDEX ETF OURO BRL B3 FUNDO DE ÍNDICE - RESPONSABILIDADE LIMITADA",
#             "tradingName": "B INDEX OURO"
#         },
#         {
#             "id": 23901,
#             "typeName": null,
#             "acronym": "SPYR",
#             "fundName": "B-INDEX ETF S&P 500 BRL FUNDO DE ÍNDICE - RESPONSABILIDADE LIMITADA",
#             "tradingName": "B INDEX SPYR"
#         },
#         {
#             "id": 6485,
#             "typeName": null,
#             "acronym": "IBOB",
#             "fundName": "BTG PACTUAL B3 IBOVESPA FUNDO DE ÍNDICE",
#             "tradingName": "PACTUAL IBOV"
#         },
#         {
#             "id": 3717,
#             "typeName": null,
#             "acronym": "ESGB",
#             "fundName": "BTG PACTUAL ESG FUNDO DE ÍNDICE S&P/B3 BRAZIL ESG",
#             "tradingName": "ETF ESG BTG"
#         },
#         {
#             "id": 22320,
#             "typeName": null,
#             "acronym": "GOLB",
#             "fundName": "BTG PACTUAL FUTURO DE OURO B3 FUNDO DE ÍNDICE",
#             "tradingName": "BTGP GOLB "
#         },
#         {
#             "id": 19294,
#             "typeName": null,
#             "acronym": "DOLB",
#             "fundName": "BTG PACTUAL REFERENCE S&P/B3 CAMBIAL FUNDO DE ÍNDICE",
#             "tradingName": "BTG SP DOLAR"
#         },
#         {
#             "id": 6784,
#             "typeName": null,
#             "acronym": "SPXB",
#             "fundName": "BTG PACTUAL S&P 500 FUNDO DE ÍNDICE",
#             "tradingName": "BTG S&P 500"
#         },
#         {
#             "id": 23167,
#             "typeName": null,
#             "acronym": "SPBZ",
#             "fundName": "BTG PACTUAL S&P 500 FUTURES QUANTO BRL FUNDO DE ÍNDICE",
#             "tradingName": "BTG SPHEDGE"
#         },
#         {
#             "id": 6501,
#             "typeName": null,
#             "acronym": "GENB",
#             "fundName": "BTG PACTUAL S&P/B3 INGENIUS FUNDO DE ÍNDICE",
#             "tradingName": "ETF BTG GENB"
#         },
#         {
#             "id": 6773,
#             "typeName": null,
#             "acronym": "SMAB",
#             "fundName": "BTG PACTUAL SMLL B3 FUNDO DE ÍNDICE",
#             "tradingName": "BTG SMLL CAP"
#         }
#     ]
# }
# Out:
# b'{"language":"pt-br","typeFund":"ETF-FII","pageNumber":1,"pageSize":20}'
# b'{"language":"pt-br","typeFund":"ETF-CRIPTO","pageNumber":1,"pageSize":20}'
# b'{"language":"pt-br","typeFund":"ETF-RF","pageNumber":1,"pageSize":20}'
# b'{"language":"pt-br","typeFund":"ETF","pageNumber":1,"pageSize":20}'

# %%
base64.b64decode(
    "eyJsYW5ndWFnZSI6InB0LWJyIiwicGFnZU51bWJlciI6MSwicGFnZVNpemUiOjIwLCJ0cmFkaW5nTmFtZSI6IkJSQVNJTCJ9"
)
# Out:
# b'{"language":"pt-br","pageNumber":1,"pageSize":20,"tradingName":"BRASIL"}'

# %%
# https://sistemaswebb3-listados.b3.com.br/listedCompaniesProxy/CompanyCall/GetListedCashDividends/eyJsYW5ndWFnZSI6InB0LWJyIiwicGFnZU51bWJlciI6MSwicGFnZVNpemUiOjIwLCJ0cmFkaW5nTmFtZSI6IkFNQkVWU0EifQ==

base64.b64decode(
    "eyJsYW5ndWFnZSI6InB0LWJyIiwicGFnZU51bWJlciI6MSwicGFnZVNpemUiOjIwLCJ0cmFkaW5nTmFtZSI6IkFNQkVWU0EifQ=="
)
# Out:
# b'{"language":"pt-br","pageNumber":1,"pageSize":20,"tradingName":"AMBEVSA"}'

# %%
url = "https://sistemaswebb3-listados.b3.com.br/fundsProxy/fundsCall/GetListedFundsSIG/eyJ0eXBlRnVuZCI6MjAsInBhZ2VOdW1iZXIiOjEsInBhZ2VTaXplIjoyMH0="

code = "eyJ0eXBlRnVuZCI6MjAsInBhZ2VOdW1iZXIiOjEsInBhZ2VTaXplIjoyMH0="

base64.b64decode(code)
# Out:
# b'{"typeFund":20,"pageNumber":1,"pageSize":20}'

# %%
"https://sistemaswebb3-listados.b3.com.br/fundsProxy/fundsCall/GetListedFundsSIG/eyJ0eXBlRnVuZCI6NywicGFnZU51bWJlciI6MSwicGFnZVNpemUiOjIwfQ=="

base64.b64decode("eyJ0eXBlRnVuZCI6NywicGFnZU51bWJlciI6MSwicGFnZVNpemUiOjIwfQ==")
# Out:
# b'{"typeFund":7,"pageNumber":1,"pageSize":20}'

# %%
"https://sistemaswebb3-listados.b3.com.br/listedCompaniesProxy/CompanyCall/GetListedFinancial/eyJjb2RlQ1ZNIjoiMjE2MTAiLCJsYW5ndWFnZSI6InB0LWJyIn0="

base64.b64decode("eyJjb2RlQ1ZNIjoiMjE2MTAiLCJsYW5ndWFnZSI6InB0LWJyIn0=")
# Out:
# b'{"codeCVM":"21610","language":"pt-br"}'

# %%
"https://sistemaswebb3-listados.b3.com.br/listedCompaniesProxy/CompanyCall/GetListFreeFloat/eyJjb2RlQ1ZNIjoiMjE2MTAiLCJsYW5ndWFnZSI6InB0LWJyIn0="

base64.b64decode("eyJjb2RlQ1ZNIjoiMjE2MTAiLCJsYW5ndWFnZSI6InB0LWJyIn0=")

"https://sistemaswebb3-listados.b3.com.br/listedCompaniesProxy/CompanyCall/GetListFines/eyJjb2RlQ1ZNIjoiMjE2MTAiLCJ5ZWFyIjowLCJsYW5ndWFnZSI6InB0LWJyIn0="

base64.b64decode("eyJjb2RlQ1ZNIjoiMjE2MTAiLCJ5ZWFyIjowLCJsYW5ndWFnZSI6InB0LWJyIn0=")

"https://sistemaswebb3-listados.b3.com.br/listedCompaniesProxy/CompanyCall/GetListedHeadLines/eyJhZ2VuY3kiOiIxOCIsImRhdGVJbml0aWFsIjoiMjAyMy0xMS0zMCIsImRhdGVGaW5hbCI6IjIwMjMtMTItMzAiLCJpc3N1aW5nQ29tcGFueSI6IihCM1NBIn0="

base64.b64decode(
    "eyJhZ2VuY3kiOiIxOCIsImRhdGVJbml0aWFsIjoiMjAyMy0xMS0zMCIsImRhdGVGaW5hbCI6IjIwMjMtMTItMzAiLCJpc3N1aW5nQ29tcGFueSI6IihCM1NBIn0="
)
# Out:
# b'{"agency":"18","dateInitial":"2023-11-30","dateFinal":"2023-12-30","issuingCompany":"(B3SA"}'
