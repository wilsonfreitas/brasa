# %%
import os
os.environ["BRASA_DATA_PATH"] = "D:\\brasa"

import sys
sys.path.append('..')

from datetime import datetime

import numpy as np
import pandas as pd

import brasa

# %%
from brasa.downloaders.downloaders import B3PagedURLEncodedDownloader
url = "https://sistemaswebb3-listados.b3.com.br/fundsProxy/fundsCall/GetListedFundsSIG"
# typeFund: 7 - FIIs - 457  funds
# typeFund: 19 - ETF de renda fixa - 11  funds
# typeFund: 20 - ETFs de renda variável - 85 funds
# typeFund: 21 - FIPs - 18 funds
# typeFund: 22 - FIPs parece igual ao 21 - 15 funds
kwargs = {
    "typeFund": 21,
    "pageNumber": 1,
    "pageSize": 100
}

dnd = B3PagedURLEncodedDownloader(url, True, **kwargs)
fp = dnd.download()
import json

fp.seek(0)
x = json.load(fp)
pd.DataFrame(x)
# Out:
#    segment acronym      fundName  \
# 0             AATH     FIP ATHON
# 1             AZIN   FIP IE AZIN
# 2             BRZP    FIP BRZ IE
# 3             BDIV  FIP BTGDV IE
# 4             ENDD  FIP END DEBT
# 5             ESUU      FIP IE I
# 6             ESUD     FIP IE II
# 7             ESUT    FIP IE III
# 8             NVRP  FIP NVRAPOSO
# 9             OPEQ  FIP INSTITUT
# 10            KNOX   FIP IE KNOX
# 11      MB    OPHF  FIP OPP HOLD
# 12            PICE  FIP PATR INF
# 13            PFIN    FIP PERFIN
# 14            FPOR  FIP PORT SUD
# 15            PPEI    FIP PRISMA
# 16            VIGT  FIP VINCI IE
# 17            XPIE  FIP XP INFRA
#
#                                           companyName  cnpj
# 0   ATHON ENERGIA ESG I FDO INV PART EM INFRAESTRU...  None
# 1                      AZ QUEST INFRA-YIELD II FIP IE  None
# 2   BRZ INFRA PORTOS FDO, INV. EM PART. INFRAESTRU...  None
# 3               BTG PACTUAL IE DIV. FDO INV. PART. IE  None
# 4            ENDURANCE DEBT FDO. INVEST. PART. INFRA.  None
# 5       FDO INV PART IE BB VOTORANTIM ENERG SUSTENT I  None
# 6      FDO INV PART IE BB VOTORANTIM ENERG SUSTENT II  None
# 7     FDO INV PART IE BB VOTORANTIM ENERG SUSTENT III  None
# 8          FDO INV PART NOVA RAPOSO - MULTIESTRATEGIA  None
# 9   INVESTIDORES INSTITUCIONAIS FDO INV PART MULTI...  None
# 10        KNOX DEBT FDO. INVEST. PART. INFRAESTRUTURA  None
# 11   OPPORTUNITY HOLDING FDO INV PART MULT INV NO EXT  None
# 12       PATRIA INFRAESTRUTURA ENERGIA CORE FIP INFRA  None
# 13        PERFIN APOLLO ENERGIA FIP EM INFRAESTRUTURA  None
# 14                   PORTO SUDESTE ROYALTIES - FIP-IE  None
# 15    PRISMA PROTON ENERGIA FDO. INVEST. PART. INFRA.  None
# 16                      VINCI ENERGIA FDO INV PART IE  None
# 17                     XP INFRA II FDO DE INV PART IE  None

# %%
from brasa import download_marketdata

download_marketdata("b3-listed-reits")
download_marketdata("b3-listed-stock-etfs")
# Out:
# Downloading b3-listed-reits   0/N/A|#                   | Elapsed Time: 0:00:00
# Downloading b3-listed-reits   0/N/A|#                   | Elapsed Time: 0:00:01
# Downloading b3-listed-stock-etfs   0/N/A|#              | Elapsed Time: 0:00:00
# Downloading b3-listed-stock-etfs   0/N/A|#              | Elapsed Time: 0:00:00

# %%
from brasa import process_marketdata

process_marketdata("b3-listed-reits")
process_marketdata("b3-listed-stock-etfs")
# Out:
# Processing b3-listed-reits   0/1  |                     | Elapsed Time: 0:00:00
# Processing b3-listed-reits   1/1  |#####################| Elapsed Time: 0:00:00
# Processing b3-listed-stock-etfs   0/1  |                | Elapsed Time: 0:00:00
# Processing b3-listed-stock-etfs   1/1  |################| Elapsed Time: 0:00:00
